# %%
import pandas as pd
import numpy as np
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('movies.csv')
df.shape
# Out:
# (4803, 24)

# %%
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
selected_features = ['genres' , 'keywords' , 'tagline' , 'cast' , 'director']
selected_features
# Out:
# ['genres', 'keywords', 'tagline', 'cast', 'director']

# %%
for i in selected_features :
    df[i].fillna('')
combined_features = df['genres'] + ' ' + df['keywords'] + ' ' + df['tagline'] + ' ' + df['cast'] + ' ' + df['director']
combined_features.dropna(inplace=True)
combined_features
# Out:
# 0       Action Adventure Fantasy Science Fiction cultu...
# 1       Adventure Fantasy Action ocean drug abuse exot...
# 2       Action Adventure Crime spy based on novel secr...
# 3       Action Crime Drama Thriller dc comics crime fi...
# 4       Action Adventure Science Fiction based on nove...
#                               ...
# 4792    Crime Horror Mystery Thriller japan prostitute...
# 4793    Drama confession hazing gang member latino lgb...
# 4795    Drama gang audition police fake homeless actre...
# 4796    Science Fiction Drama Thriller distrust garage...
# 4798    Action Crime Thriller united states\u2013mexic...
# Length: 3757, dtype: object

# %%
list_of_all_titles = df['title'].tolist()
list_of_all_titles
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
#  'Transformers: Revenge of the Fallen',
# ...

# %%
movie_name = input("Enter your favorite movie name : ")
# Out:
# Enter your favorite movie name :  iron man

# %%
movie_name2 = input("Enter your favorite movie name : ")
# Out:
# Enter your favorite movie name :  iron man

# %%
movie_name3 = input("Enter your favorite movie name : ")
find_close_title = difflib.get_close_matches(movie_name3 , list_of_all_titles)
find_close_title
index_of_the_movie = df[df.title == find_close_title[0]]['index'].values[0]
index_of_the_movie
# Out:
# Enter your favorite movie name :  iron man
# 68

# %%
vectorizer = TfidfVectorizer()

# %%
feature_vectors = vectorizer.fit_transform(combined_features)
print(feature_vectors)
# Out:
#   (0, 184)	0.07730030469761222
#   (0, 244)	0.08761832770476981
#   (0, 4531)	0.10884008565454713
#   (0, 11598)	0.10162340157558672
#   (0, 4672)	0.10162340157558672
#   (0, 3151)	0.2183472672840518
#   (0, 2603)	0.2234527578396162
#   (0, 5016)	0.16231873789167722
#   (0, 12278)	0.33706405674362216
#   (0, 14165)	0.1263712397025473
#   (0, 2744)	0.25244839623226556
#   (0, 12186)	0.2139246902011623
#   (0, 4238)	0.23688181493087848
#   (0, 13042)	0.0662280667693844
#   (0, 14542)	0.12593255607069875
#   (0, 9534)	0.08734535805520414
#   (0, 9805)	0.26936700729904856
#   (0, 11385)	0.14977293661066507
#   (0, 14551)	0.2329808254780701
#   (0, 14773)	0.20823298735110954
#   (0, 11358)	0.2208017329558662
#   (0, 12000)	0.20190521307222728
#   (0, 14239)	0.19539014255433562
#   (0, 12479)	0.1528997976336656
#   (0, 7469)	0.23688181493087848
#   :	:
#   (3756, 7893)	0.2975105254145644
#   (3756, 5847)	0.09300733675902982
#   (3756, 3343)	0.1087487611305808
# ...

# %%
similarity = cosine_similarity(feature_vectors)
print(similarity.shape)
# Out:
# (3757, 3757)

# %%
similarity_score = list(enumerate(similarity[index_of_the_movie]))
similarity_score
# Out:
# [(0, 0.0452018549414524),
#  (1, 0.028520976781631898),
#  (2, 0.04319648698415247),
#  (3, 0.13863488825589862),
#  (4, 0.03263292864286392),
#  (5, 0.026150158916314913),
#  (6, 0.007596623509022856),
#  (7, 0.03421177967947053),
#  (8, 0.03288390225569649),
#  (9, 0.10503429519333657),
#  (10, 0.05520768310775114),
#  (11, 0.025675779702621776),
#  (12, 0.012323323881619375),
#  (13, 0.1415539363267715),
#  (14, 0.018296729588837057),
#  (15, 0.03248232628444985),
#  (16, 0.024515630815095328),
#  (17, 0.06105760216338807),
#  (18, 0.02187623764549907),
#  (19, 0.025074464191351856),
#  (20, 0.01131934078348944),
#  (21, 0.017433075051759006),
#  (22, 0.030161350976917328),
#  (23, 0.012584039536636851),
#  (24, 0.0),
#  (25, 0.035070280359211746),
#  (26, 0.030651491980070125),
#  (27, 0.03348740713538779),
#  (28, 0.03508558778939423),
#  (29, 0.051147261237947175),
#  (30, 0.03326024178513572),
#  (31, 0.02854497478223554),
#  (32, 0.03401741954952462),
#  (33, 0.0),
# ...

# %%
sorted_similar_movies = sorted(similarity_score , key = lambda x:x[1], reverse = True)
print(sorted_similar_movies)
# Out:
# [(68, 1.0000000000000002), (782, 0.18364042464678126), (2251, 0.14967232797211555), (13, 0.1415539363267715), (631, 0.14139432338063246), (585, 0.14121022838348027), (289, 0.1400789452955541), (1387, 0.13996166398762352), (3, 0.13863488825589862), (202, 0.13844242164033532), (330, 0.13127468164349035), (113, 0.13069806392033084), (60, 0.12989839880549595), (63, 0.1269514427800995), (40, 0.12596021521787384), (832, 0.1253379782679509), (1276, 0.12124146158667376), (288, 0.11892661363629653), (1133, 0.11765502967023453), (229, 0.1173501138083241), (1077, 0.11728790559276386), (985, 0.11666247201306425), (156, 0.11484005235679376), (2200, 0.11460266977054515), (415, 0.11363315853494868), (919, 0.10935024644856169), (1096, 0.10810507404286852), (3420, 0.10754452506503706), (508, 0.1062526559040575), (106, 0.10606397541152343), (216, 0.10576308063033885), (295, 0.10564029303499682), (9, 0.10503429519333657), (3493, 0.10488593619875816), (1210, 0.10423669097835647), (1220, 0.10028898834367
# ...

# %%
print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
    index = movie[0]
    title_from_index = df[df.index == index]['title'].values[0]
    if i<10 :
        print(i , ',' , title_from_index)
        i += 1
# Out:
# Movies suggested for you :
#
# 1 , Iron Man
# 2 , The Spirit
# 3 , My All American
# 4 , The Lone Ranger
# 5 , Ice Age
# 6 , War Horse
# 7 , The Emperor's New Groove
# 8 , Malcolm X
# 9 , The Dark Knight Rises

# %%
import pandas as pd
import numpy as np
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
movie_name5 = input("Enter your favorite movie name : ")
df = pd.read_csv('movies.csv')
list_of_all_titles = df['title'].tolist()
find_close_title = difflib.get_close_matches(movie_name5 , list_of_all_titles)
index_of_the_movie = df[df.title == find_close_title[0]]['index'].values[0]
vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(combined_features)

similarity = cosine_similarity(feature_vectors)
similarity_score = list(enumerate(similarity[index_of_the_movie]))
sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True)
print('Movies suggested for you : \n')
i=1
for movie in sorted_similar_movies:
    index = movie[0]
    title_from_index = df[df.index == index]['title'].values[0]
    if i<30 :
        print(i , ',' , title_from_index)
        i += 1
# Out:
# Enter your favorite movie name :  iron man
# Movies suggested for you :
#
# 1 , Iron Man
# 2 , The Spirit
# 3 , My All American
# 4 , The Lone Ranger
# 5 , Ice Age
# 6 , War Horse
# 7 , The Emperor's New Groove
# 8 , Malcolm X
# 9 , The Dark Knight Rises
